# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./cereal.csv')
df=df.set_index('name')
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
df = df.sort_values(['rating'],ascending=False)
plt.figure(figsize=(20,20))
sns.barplot(x=df["rating"],y=df.index, color="b")
plt.xlabel("Product Name",fontsize=20)
plt.ylabel("Rating",fontsize=20)
plt.title("Product Rating",fontsize=20)
plt.show()

# %%
corr = df.corr()
corr
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.019066  0.498610  0.300649 -0.293413  0.250681
# protein   0.019066  1.000000  0.208431 -0.054674  0.500330 -0.130864
# fat       0.498610  0.208431  1.000000 -0.005407  0.016719 -0.318043
# sodium    0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.355983
# fiber    -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.356083
# carbo     0.250681 -0.130864 -0.318043  0.355983 -0.356083  1.000000
# sugars    0.562340 -0.329142  0.270819  0.101451 -0.141205 -0.331665
# potass   -0.066609  0.549407  0.193279 -0.032603  0.903374 -0.349685
# vitamins  0.265356  0.007335 -0.031156  0.361477 -0.032243  0.258148
# shelf     0.097234  0.133865  0.263691 -0.069719  0.297539 -0.101790
# weight    0.696091  0.216158  0.214625  0.308576  0.247226  0.135136
# cups      0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.363932
# rating   -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.052055
#
# ...

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)

# %%
df2=df.loc[["All-Bran with Extra Fiber","100% Bran","Shredded Wheat 'n'Bran", "Shredded Wheat spoon size", "Shredded Wheat"]]
df2=df2.reset_index()

# %%
df2.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 1                  100% Bran   N    C        70        4    1     130   10.0
# 2     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 3  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 4             Shredded Wheat   N    C        80        2    0       0    3.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    8.0       0     330        25      3    1.00  0.50  93.704912
# 1    5.0       6     280        25      3    1.00  0.33  68.402973
# 2   19.0       0     140         0      1    1.00  0.67  74.472949
# 3   20.0       0     120         0      1    1.00  0.67  72.801787
# 4   16.0       0      95         0      1    0.83  1.00  68.235885

# %%
f, axes = plt.subplots(2,3, figsize=(20, 12))
ax = sns.distplot(df["calories"], ax=axes[0,0])
ax = sns.distplot(df["sugars"], ax=axes[0,1])
ax = sns.distplot(df["protein"], ax=axes[0,2])
ax = sns.distplot(df["fiber"], ax=axes[1,0])
ax = sns.distplot(df["potass"], ax=axes[1,1])
ax = sns.distplot(df["rating"], ax=axes[1,2])

# %%
ax = sns.distplot(df["sugars"])

# %%
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 100% Bran                   N    C        70        4    1     130   10.0
# Shredded Wheat              N    C        80        2    0       0    3.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# All-Bran with Extra Fiber    8.0       0     330        25      3    1.00
# Shredded Wheat 'n'Bran      19.0       0     140         0      1    1.00
# Shredded Wheat spoon size   20.0       0     120         0      1    1.00
# 100% Bran                    5.0       6     280        25      3    1.00
# Shredded Wheat              16.0       0      95         0      1    0.83
#
#                            cups     rating
# name
# ...

# %%
df3=df.loc[:,"mfr"]
df3.value_counts()
# Out:
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %%
df3.value_counts().plot(kind='bar')

# %%
from scipy.stats import pearsonr
data1 = df.loc[:,"rating"]
data2 = df.loc[:,"calories"]
stat, p = pearsonr(data1, data2)
print('stat=%.5f, p=%.5f' % (stat, p))
if p > 0.05:
    print('Probably independent')
else:
    print('Probably dependent')
# Out:
# stat=-0.68938, p=0.00000
# Probably dependent

# %%
from scipy import stats
a = data1
b = data2
stats.pearsonr(a, b)
# Out:
# (-0.6893760311652586, 4.140277400006435e-12)
